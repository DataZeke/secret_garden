# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Zeke Chavez**
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I want to chart out video game and fitness trends.*

# %% [markdown]
# ###The code is Cell 5 will print the text: Hello World.

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# Here are a list of languages I ~need~ want to learn:
# - Spanish
# - Korean
# - Japanese
# ![Flag_of_Mexico_(1934-1968).svg.png](attachment:d2ead3a1-438b-4d46-8c79-6696730a7c75.png)
